# %%
# importing libraries
import os 
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt 
from shapely.geometry import Point

# %%
data1 = pd.read_csv("C:\\Users\\kaitai\\Downloads\\Book1.csv") # reading the csv file
data1
# Out:
#     POPULATION  YEAR
# 0    331449281  2020
# 1  308,745,538  2010

# %%
import matplotlib.pyplot as plt  #plotting the bars of US polulation versus year

fig, ax = plt.subplots()

YEAR = ['2010','2020']
YEAR = [308745538, 331449281]
bar_labels = ['red', 'orange']
bar_colors = ['tab:red', 'tab:orange']

ax.bar(POPULATION, YEAR, label=bar_labels, color=bar_colors)

ax.set_ylabel('POPULATION')
ax.set_xlabel('YEAR')
ax.set_title('US CENSUS BUREAU FOR THE YEARS 2010-2020')
ax.legend(title='YEAR color')

plt.show()
